# %% [markdown]
# #Spotify API Data Report
# #Hypothesis: With heavier music becoming more mainstream, other genres have had to adapt to the changing sound and population.
# #In doing so, genres such as rock 'n roll have increased their loudness as well as their danceability over the years at the expense of intrumentalness.
# #Comparing Maneskin (Newer Alt Rock 'n Roll) and AC/DC (Older Rock 'n Roll)
# #This data is reliable due to the information coming directly from Spotify which is a very popular streaming service.
# #This data is unreliable because Spotify renews its data and so the data is newer data and not taken over the entire time that the album has been out.
# # It also only has data relating to the amount of streams on Spotify and does not account for any other music streaming app.
# #Some problems with this data is that it is not completely accurate due to it being taken from only one streaming platform.
# #Some other streaming platforms might have these bands under different genres than what Spotify has them under which could affect their popularity.
# #The endpoint that I will be focusing on is the spotify audio_features.

# %%
import pandas as pd
import json
import urllib
import base64
import requests

# %% [markdown]
# The above code imports important libraries that are needed to run the code

# %%
def get_session_token(SessionID, SessionKey):
    url = 'https://accounts.spotify.com/api/token'
    data = {'grant_type':'client_credentials'}
    encoded_key = base64.b64encode(str(SessionID + ":" + SessionKey).encode("ascii"))
    header = {'Authorization': 'Basic {}'.format(encoded_key.decode("ascii"))}
    response = requests.post(url, data = data, headers = header)
    print(response.status_code)
    return response.json()['access_token']

# %% [markdown]
# The above code creates a function that generates an access token which is needed to access the spotify data.
# It takes in the url, the data gateway, a personalized encoded key, and an authorization code and returns the response as the access key

# %%
keys = pd.read_csv("Spotify_Keys.txt")

# %% [markdown]
# Keys = the text file that has the client id as well as the client secret codes.
# Assigning these values to a variable makes it easier to use them

# %%
access_token = get_session_token(keys['Client_ID'].iloc[0], keys['Client_Secret'].iloc[0])
# Out:
# 200

# %% [markdown]
# This checks to see if there are any problems associated with the keys and returns a value based on what error might occure
# If there is no error, it should return a value of 200

# %%
t_features_ep = 'https://api.spotify.com/v1/audio-features'
tracks_ep = 'https://api.spotify.com/v1/tracks'
ab_tracks_ep = 'https://api.spotify.com/v1/albums/{}/tracks'

# %% [markdown]
# Assigns different urls to variables so that they are easier to be used later in the code

# %%
def api_call(endpoint_url, api_header):
    response = requests.get(endpoint_url, headers = api_header)
    print(response.status_code)
    return response.json()

# %% [markdown]
# Creates a function that takes an enpoint_url along with an api_header and returns a response code
# This response code determines on whether the spotify data base was reached
# This should return a value of 200

# %%
session_header = {'Authorization': 'Bearer {}'.format(access_token)}

# %% [markdown]
# Uses the access token to access the data by authenticating it

# %%
first_album_id = "2kcJ3TxBhSwmki0QWFXUz8"

# %% [markdown]
# Gets the album id from spotify and assigns that to a variable for easier use (RUSH! ARE YOU COMING? (2023))

# %%
second_album_id = "6mUdeDZCsExyJLMdAfDuwh"

# %% [markdown]
# Gets the album id from spotify and assigns that to a variable for easier use (Back In Black (1980))

# %%
ab_tracks_ep.format(first_album_id)
# Out:
# 'https://api.spotify.com/v1/albums/2kcJ3TxBhSwmki0QWFXUz8/tracks'

# %% [markdown]
# Formats the first album id into a url that can be read

# %%
ab_tracks_ep.format(second_album_id)
# Out:
# 'https://api.spotify.com/v1/albums/6mUdeDZCsExyJLMdAfDuwh/tracks'

# %% [markdown]
# Formats the second album id into a url that can be read

# %%
first_album_response = api_call(ab_tracks_ep.format(first_album_id), session_header)
second_album_response = api_call(ab_tracks_ep.format(second_album_id), session_header)
# Out:
# 200
# 200

# %% [markdown]
# Calls into spotify to get the data for the first and the second albums and places that data into a new variable for easier use

# %%
first_df = pd.DataFrame(first_album_response['items'])
second_df = pd.DataFrame(second_album_response['items'])
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       167276     False  {'spotify': 'https://open.spotify.com/track/7G...
# 1       216997     False  {'spotify': 'https://open.spotify.com/track/5m...
# 2       149835     False  {'spotify': 'https://open.spotify.com/track/0c...
# 3       188136     False  {'spotify': 'https://open.spotify.com/track/0s...
# 4       182301     False  {'spotify': 'https://open.spotify.com/track/3w...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/7GJRZmyEpMIo...  7GJRZmyEpMIou1RqG0ebd8
# 1  https://api.spotify.com/v1/tracks/5mY6WIHXoBsO...  5mY6WIHXoBsOCSyQxrTg0E
# 2  https://api.spotify.com/v1/tracks/0cyQuiFTVaHM...  0cyQuiFTVaHM70y8xRsOWA
# 3  https://api.spotify.com/v1/tracks/0sZHxhoBaK0Y...  0sZHxhoBaK0YEvvMV8blr6
# 4  https://api.spotify.com/v1/tracks/3wy4se12ucUN...  3wy4se12ucUNAfRwZpmDuz
#
#                     name                                        preview_url  \
# 0  HONEY (ARE U COMING?)  https://p.scdn.co/mp3-preview/3fe024604adacec1...
# 1              VALENTINE  https://p.scdn.co/mp3-preview/1712dcb919665a9b...
# 2            OFF MY FACE  https://p.scdn.co/mp3-preview/e1b3d8a2b268b17e...
# 3             THE DRIVER  https://p.scdn.co/mp3-preview/72be7cc52c4e5607...
# 4             TRASTEVERE  https://p.scdn.co/mp3-preview/25d6ac4def73ba6f...
#
#    track_number   type                                   uri  is_local
# 0             1  track  spotify:track:7GJRZmyEpMIou1RqG0ebd8     False
# 1             2  track  spotify:track:5mY6WIHXoBsOCSyQxrTg0E     False
# 2             3  track  spotify:track:0cyQuiFTVaHM70y8xRsOWA     False
# 3             4  track  spotify:track:0sZHxhoBaK0YEvvMV8blr6     False
# 4             5  track  spotify:track:3wy4se12ucUNAfRwZpmDuz     False

# %% [markdown]
# Creates data frames that can be used and shows the first 5 tracks of the album

# %%
ms_track_ids = ','.join(first_df['id'].to_list())
ac_track_ids = ','.join(second_df['id'].to_list())

# %% [markdown]
# Joins the track ids to make a definitive list that would be easier to look at and use

# %%
t_features_ep + '?ids={}'.format(ms_track_ids)
# Out:
# 'https://api.spotify.com/v1/audio-features?ids=7GJRZmyEpMIou1RqG0ebd8,5mY6WIHXoBsOCSyQxrTg0E,0cyQuiFTVaHM70y8xRsOWA,0sZHxhoBaK0YEvvMV8blr6,3wy4se12ucUNAfRwZpmDuz,1yORwrLynitfD8HoPipXlg,5FjRyRqZlgrM4tfzVhIKGA,0WbzKaO91ulIuqn3WNbEiT,17PVZrZPFBjFhNqx0YLF7o,5qFoSIpmfXexkhCpD1E1aY,6k01DY0P3ztcD75wSYWUsk,6pUcoYKUZzgBNokZ3IYCfA,1SBNKGLIg5uZgSTjZhSTMr,0JlowC3ck7YYDm1mACwHwF,3kpTSEwdJAzygDttaU0614,6nzBnBFS64mfZRHj4ncdx6,66F8TOWVZ6bAdS7oVZ52in,2uiUNqiTH1prcwDZ47OMRX,5QoKT6BRoQwtP1Z7mH7vWV,2y5ljQNRVVP1VVkHw0XsBG'

# %% [markdown]
# Formats the tracks and uses the session token to access their data

# %%
ms_track_features = api_call(t_features_ep + '?ids={}'.format(ms_track_ids), session_header)
ac_track_features = api_call(t_features_ep + '?ids={}'.format(ac_track_ids), session_header)
# Out:
# 200
# 200

# %% [markdown]
# Calls to the Spotiy API to gather the track's features. If successful, it should return a status code.
# Should return a status code of 200

# %%
ms_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(ms_track_ids), session_header)
ac_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(ac_track_ids), session_header)
# Out:
# 200
# 200

# %% [markdown]
# Calls to the Spotify API to check to see if the track is within the market of the US then returns a status code
# #Should return a 200

# %%
ms_track_features['audio_features']
# Out:
# [{'danceability': 0.475,
#   'energy': 0.939,
#   'key': 7,
#   'loudness': -2.353,
#   'mode': 0,
#   'speechiness': 0.0798,
#   'acousticness': 0.00208,
#   'instrumentalness': 1.6e-06,
#   'liveness': 0.159,
#   'valence': 0.375,
#   'tempo': 139.988,
#   'type': 'audio_features',
#   'id': '7GJRZmyEpMIou1RqG0ebd8',
#   'uri': 'spotify:track:7GJRZmyEpMIou1RqG0ebd8',
#   'track_href': 'https://api.spotify.com/v1/tracks/7GJRZmyEpMIou1RqG0ebd8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GJRZmyEpMIou1RqG0ebd8',
#   'duration_ms': 167277,
#   'time_signature': 4},
#  {'danceability': 0.475,
#   'energy': 0.716,
#   'key': 2,
#   'loudness': -4.526,
#   'mode': 0,
#   'speechiness': 0.0277,
#   'acousticness': 0.00706,
#   'instrumentalness': 7.28e-06,
#   'liveness': 0.13,
#   'valence': 0.217,
#   'tempo': 94.967,
#   'type': 'audio_features',
#   'id': '5mY6WIHXoBsOCSyQxrTg0E',
#   'uri': 'spotify:track:5mY6WIHXoBsOCSyQxrTg0E',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mY6WIHXoBsOCSyQxrTg0E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mY6WIHXoBsOCSyQxrTg0E',
#   'duration_ms': 216998,
#   'time_signature': 4},
#  {'danceability': 0.794,
#   'energy': 0.801,
#   'key': 11,
#   'loudness': -3.006,
#   'mode': 0,
#   'speechiness': 0.0603,
#   'acousticness': 0.00195,
#   'instrumentalness': 0,
#   'liveness': 0.359,
#   'valence': 0.864,
#   'tempo': 119.997,
#   'type': 'audio_features',
#   'id': '0cyQuiFTVaHM70y8xRsOWA',
#   'uri': 'spotify:track:0cyQuiFTVaHM70y8xRsOWA',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cyQuiFTVaHM70y8xRsOWA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cyQuiFTVaHM70y8xRsOWA',
#   'duration_ms': 149835,
#   'time_signature': 4},
#  {'danceability': 0.321,
#   'energy': 0.827,
#   'key': 9,
#   'loudness': -4.238,
#   'mode': 0,
#   'speechiness': 0.0878,
#   'acousticness': 0.000851,
#   'instrumentalness': 0,
#   'liveness': 0.306,
#   'valence': 0.333,
#   'tempo': 139.081,
#   'type': 'audio_features',
#   'id': '0sZHxhoBaK0YEvvMV8blr6',
#   'uri': 'spotify:track:0sZHxhoBaK0YEvvMV8blr6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0sZHxhoBaK0YEvvMV8blr6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0sZHxhoBaK0YEvvMV8blr6',
#   'duration_ms': 188136,
#   'time_signature': 4},
#  {'danceability': 0.604,
#   'energy': 0.542,
#   'key': 11,
#   'loudness': -2.942,
#   'mode': 0,
#   'speechiness': 0.0242,
#   'acousticness': 0.605,
#   'instrumentalness': 0,
#   'liveness': 0.171,
#   'valence': 0.463,
#   'tempo': 100.014,
#   'type': 'audio_features',
#   'id': '3wy4se12ucUNAfRwZpmDuz',
#   'uri': 'spotify:track:3wy4se12ucUNAfRwZpmDuz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wy4se12ucUNAfRwZpmDuz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wy4se12ucUNAfRwZpmDuz',
#   'duration_ms': 182302,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.756,
#   'key': 1,
#   'loudness': -4.783,
#   'mode': 0,
#   'speechiness': 0.026,
#   'acousticness': 0.000926,
#   'instrumentalness': 0.000116,
#   'liveness': 0.0486,
#   'valence': 0.681,
#   'tempo': 114.012,
#   'type': 'audio_features',
#   'id': '1yORwrLynitfD8HoPipXlg',
#   'uri': 'spotify:track:1yORwrLynitfD8HoPipXlg',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yORwrLynitfD8HoPipXlg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yORwrLynitfD8HoPipXlg',
#   'duration_ms': 191856,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.821,
#   'key': 9,
#   'loudness': -2.974,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'acousticness': 0.00181,
#   'instrumentalness': 0,
#   'liveness': 0.0981,
#   'valence': 0.915,
#   'tempo': 139.916,
#   'type': 'audio_features',
#   'id': '5FjRyRqZlgrM4tfzVhIKGA',
#   'uri': 'spotify:track:5FjRyRqZlgrM4tfzVhIKGA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FjRyRqZlgrM4tfzVhIKGA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FjRyRqZlgrM4tfzVhIKGA',
#   'duration_ms': 168280,
#   'time_signature': 4},
#  {'danceability': 0.48,
#   'energy': 0.585,
#   'key': 4,
#   'loudness': -4.196,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.00277,
#   'instrumentalness': 0,
#   'liveness': 0.0623,
#   'valence': 0.269,
#   'tempo': 84.802,
#   'type': 'audio_features',
#   'id': '0WbzKaO91ulIuqn3WNbEiT',
#   'uri': 'spotify:track:0WbzKaO91ulIuqn3WNbEiT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WbzKaO91ulIuqn3WNbEiT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WbzKaO91ulIuqn3WNbEiT',
#   'duration_ms': 179631,
#   'time_signature': 3},
#  {'danceability': 0.735,
#   'energy': 0.729,
#   'key': 2,
#   'loudness': -3.338,
#   'mode': 1,
#   'speechiness': 0.0783,
#   'acousticness': 0.0157,
#   'instrumentalness': 0,
#   'liveness': 0.16,
#   'valence': 0.88,
#   'tempo': 147.026,
#   'type': 'audio_features',
#   'id': '17PVZrZPFBjFhNqx0YLF7o',
#   'uri': 'spotify:track:17PVZrZPFBjFhNqx0YLF7o',
#   'track_href': 'https://api.spotify.com/v1/tracks/17PVZrZPFBjFhNqx0YLF7o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17PVZrZPFBjFhNqx0YLF7o',
#   'duration_ms': 184660,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.715,
#   'key': 6,
#   'loudness': -4.04,
#   'mode': 0,
#   'speechiness': 0.0323,
#   'acousticness': 0.00098,
#   'instrumentalness': 0,
#   'liveness': 0.0781,
#   'valence': 0.598,
#   'tempo': 131.01,
#   'type': 'audio_features',
#   'id': '5qFoSIpmfXexkhCpD1E1aY',
#   'uri': 'spotify:track:5qFoSIpmfXexkhCpD1E1aY',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qFoSIpmfXexkhCpD1E1aY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qFoSIpmfXexkhCpD1E1aY',
#   'duration_ms': 164682,
#   'time_signature': 4},
#  {'danceability': 0.567,
#   'energy': 0.692,
#   'key': 5,
#   'loudness': -3.743,
#   'mode': 0,
#   'speechiness': 0.063,
#   'acousticness': 0.000217,
#   'instrumentalness': 0.0479,
#   'liveness': 0.106,
#   'valence': 0.351,
#   'tempo': 128.047,
#   'type': 'audio_features',
#   'id': '6k01DY0P3ztcD75wSYWUsk',
#   'uri': 'spotify:track:6k01DY0P3ztcD75wSYWUsk',
#   'track_href': 'https://api.spotify.com/v1/tracks/6k01DY0P3ztcD75wSYWUsk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6k01DY0P3ztcD75wSYWUsk',
#   'duration_ms': 221062,
#   'time_signature': 4},
#  {'danceability': 0.626,
#   'energy': 0.652,
#   'key': 9,
#   'loudness': -3.519,
#   'mode': 1,
#   'speechiness': 0.1,
#   'acousticness': 0.00041,
#   'instrumentalness': 0.00574,
#   'liveness': 0.0781,
#   'valence': 0.571,
#   'tempo': 124.914,
#   'type': 'audio_features',
#   'id': '6pUcoYKUZzgBNokZ3IYCfA',
#   'uri': 'spotify:track:6pUcoYKUZzgBNokZ3IYCfA',
#   'track_href': 'https://api.spotify.com/v1/tracks/6pUcoYKUZzgBNokZ3IYCfA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pUcoYKUZzgBNokZ3IYCfA',
#   'duration_ms': 167970,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.914,
#   'key': 2,
#   'loudness': -4.873,
#   'mode': 1,
#   'speechiness': 0.0521,
#   'acousticness': 2.99e-05,
#   'instrumentalness': 0.00021,
#   'liveness': 0.342,
#   'valence': 0.766,
#   'tempo': 134.014,
#   'type': 'audio_features',
#   'id': '1SBNKGLIg5uZgSTjZhSTMr',
#   'uri': 'spotify:track:1SBNKGLIg5uZgSTjZhSTMr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SBNKGLIg5uZgSTjZhSTMr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SBNKGLIg5uZgSTjZhSTMr',
#   'duration_ms': 156057,
#   'time_signature': 4},
#  {'danceability': 0.489,
#   'energy': 0.801,
#   'key': 1,
#   'loudness': -2.357,
#   'mode': 1,
#   'speechiness': 0.0813,
#   'acousticness': 0.00351,
#   'instrumentalness': 1.03e-05,
#   'liveness': 0.144,
#   'valence': 0.29,
#   'tempo': 154.771,
#   'type': 'audio_features',
#   'id': '0JlowC3ck7YYDm1mACwHwF',
#   'uri': 'spotify:track:0JlowC3ck7YYDm1mACwHwF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JlowC3ck7YYDm1mACwHwF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JlowC3ck7YYDm1mACwHwF',
#   'duration_ms': 163177,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.433,
#   'key': 9,
#   'loudness': -6.585,
#   'mode': 1,
#   'speechiness': 0.0283,
#   'acousticness': 0.587,
#   'instrumentalness': 0.000173,
#   'liveness': 0.0942,
#   'valence': 0.291,
#   'tempo': 138.981,
#   'type': 'audio_features',
#   'id': '3kpTSEwdJAzygDttaU0614',
#   'uri': 'spotify:track:3kpTSEwdJAzygDttaU0614',
#   'track_href': 'https://api.spotify.com/v1/tracks/3kpTSEwdJAzygDttaU0614',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kpTSEwdJAzygDttaU0614',
#   'duration_ms': 194875,
#   'time_signature': 3},
#  {'danceability': 0.547,
#   'energy': 0.856,
#   'key': 7,
#   'loudness': -5.183,
#   'mode': 1,
#   'speechiness': 0.0517,
#   'acousticness': 0.000183,
#   'instrumentalness': 7.79e-05,
#   'liveness': 0.0771,
#   'valence': 0.687,
#   'tempo': 131.951,
#   'type': 'audio_features',
#   'id': '6nzBnBFS64mfZRHj4ncdx6',
#   'uri': 'spotify:track:6nzBnBFS64mfZRHj4ncdx6',
#   'track_href': 'https://api.spotify.com/v1/tracks/6nzBnBFS64mfZRHj4ncdx6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nzBnBFS64mfZRHj4ncdx6',
#   'duration_ms': 150696,
#   'time_signature': 4},
#  {'danceability': 0.443,
#   'energy': 0.962,
#   'key': 4,
#   'loudness': -1.844,
#   'mode': 0,
#   'speechiness': 0.0638,
#   'acousticness': 0.00179,
#   'instrumentalness': 0,
#   'liveness': 0.424,
#   'valence': 0.234,
#   'tempo': 172.967,
#   'type': 'audio_features',
#   'id': '66F8TOWVZ6bAdS7oVZ52in',
#   'uri': 'spotify:track:66F8TOWVZ6bAdS7oVZ52in',
#   'track_href': 'https://api.spotify.com/v1/tracks/66F8TOWVZ6bAdS7oVZ52in',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/66F8TOWVZ6bAdS7oVZ52in',
#   'duration_ms': 220168,
#   'time_signature': 4},
#  {'danceability': 0.504,
#   'energy': 0.981,
#   'key': 2,
#   'loudness': -2.265,
#   'mode': 1,
#   'speechiness': 0.0926,
#   'acousticness': 0.00134,
#   'instrumentalness': 0,
#   'liveness': 0.206,
#   'valence': 0.571,
#   'tempo': 112.477,
#   'type': 'audio_features',
#   'id': '2uiUNqiTH1prcwDZ47OMRX',
#   'uri': 'spotify:track:2uiUNqiTH1prcwDZ47OMRX',
#   'track_href': 'https://api.spotify.com/v1/tracks/2uiUNqiTH1prcwDZ47OMRX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2uiUNqiTH1prcwDZ47OMRX',
#   'duration_ms': 200585,
#   'time_signature': 4},
#  {'danceability': 0.292,
#   'energy': 0.776,
#   'key': 7,
#   'loudness': -4.455,
#   'mode': 0,
#   'speechiness': 0.0278,
#   'acousticness': 0.00067,
#   'instrumentalness': 0.0144,
#   'liveness': 0.122,
#   'valence': 0.31,
#   'tempo': 101.064,
#   'type': 'audio_features',
#   'id': '5QoKT6BRoQwtP1Z7mH7vWV',
#   'uri': 'spotify:track:5QoKT6BRoQwtP1Z7mH7vWV',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QoKT6BRoQwtP1Z7mH7vWV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QoKT6BRoQwtP1Z7mH7vWV',
#   'duration_ms': 224762,
#   'time_signature': 4},
#  {'danceability': 0.767,
#   'energy': 0.676,
#   'key': 1,
#   'loudness': -3.282,
#   'mode': 0,
#   'speechiness': 0.0646,
#   'acousticness': 0.000621,
#   'instrumentalness': 0,
#   'liveness': 0.0977,
#   'valence': 0.792,
#   'tempo': 142.059,
#   'type': 'audio_features',
#   'id': '2y5ljQNRVVP1VVkHw0XsBG',
#   'uri': 'spotify:track:2y5ljQNRVVP1VVkHw0XsBG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2y5ljQNRVVP1VVkHw0XsBG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2y5ljQNRVVP1VVkHw0XsBG',
#   'duration_ms': 186809,
#   'time_signature': 4}]

# %% [markdown]
# Shows the audio features within the album for Maneskin. Only looking for danceability, loudness, and intrumentalness

# %%
ms_features_df = pd.DataFrame(ms_track_features['audio_features'])
ac_features_df = pd.DataFrame(ac_track_features['audio_features'])

# %% [markdown]
# Creates a dataframe for both Maneskin and AC/DC based on the 'audio_features'

# %%
ms_tracks_df = pd.DataFrame(ms_track_info['tracks'])
ac_tracks_df = pd.DataFrame(ac_track_info['tracks'])
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       167276     False  {'isrc': 'ITB002301189'}
# 1       216997     False  {'isrc': 'ITB002301339'}
# 2       149835     False  {'isrc': 'ITB002301343'}
# 3       188136     False  {'isrc': 'ITB002301341'}
# 4       182301     False  {'isrc': 'ITB002301345'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/7G...
# 1  {'spotify': 'https://open.spotify.com/track/5m...
# 2  {'spotify': 'https://open.spotify.com/track/0c...
# 3  {'spotify': 'https://open.spotify.com/track/0s...
# 4  {'spotify': 'https://open.spotify.com/track/3w...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/7GJRZmyEpMIo...  7GJRZmyEpMIou1RqG0ebd8
# 1  https://api.spotify.com/v1/tracks/5mY6WIHXoBsO...  5mY6WIHXoBsOCSyQxrTg0E
# 2  https://api.spotify.com/v1/tracks/0cyQuiFTVaHM...  0cyQuiFTVaHM70y8xRsOWA
# 3  https://api.spotify.com/v1/tracks/0sZHxhoBaK0Y...  0sZHxhoBaK0YEvvMV8blr6
# 4  https://api.spotify.com/v1/tracks/3wy4se12ucUN...  3wy4se12ucUNAfRwZpmDuz
#
#    is_local  is_playable                   name  popularity  \
# 0     False         True  HONEY (ARE U COMING?)          57
# 1     False         True              VALENTINE          65
# 2     False         True            OFF MY FACE          65
# 3     False         True             THE DRIVER          64
# 4     False         True             TRASTEVERE          60
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/3fe024604adacec1...             1  track
# 1  https://p.scdn.co/mp3-preview/1712dcb919665a9b...             2  track
# 2  https://p.scdn.co/mp3-preview/e1b3d8a2b268b17e...             3  track
# 3  https://p.scdn.co/mp3-preview/72be7cc52c4e5607...             4  track
# 4  https://p.scdn.co/mp3-preview/25d6ac4def73ba6f...             5  track
#
#                                     uri
# 0  spotify:track:7GJRZmyEpMIou1RqG0ebd8
# 1  spotify:track:5mY6WIHXoBsOCSyQxrTg0E
# 2  spotify:track:0cyQuiFTVaHM70y8xRsOWA
# 3  spotify:track:0sZHxhoBaK0YEvvMV8blr6
# 4  spotify:track:3wy4se12ucUNAfRwZpmDuz

# %% [markdown]
# Creates a dataframe based off of 'tracks' for both Maneskin and AC/DC and shows the first 5 of Maneskin

# %%
ms_merged = pd.merge(ms_features_df, ms_tracks_df, how = 'inner', on = 'id')
ms_merged.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.475   0.939    7    -2.353     0       0.0798      0.002080
# 1         0.475   0.716    2    -4.526     0       0.0277      0.007060
# 2         0.794   0.801   11    -3.006     0       0.0603      0.001950
# 3         0.321   0.827    9    -4.238     0       0.0878      0.000851
# 4         0.604   0.542   11    -2.942     0       0.0242      0.605000
#
#    instrumentalness  liveness  valence  ...  \
# 0          0.000002     0.159    0.375  ...
# 1          0.000007     0.130    0.217  ...
# 2          0.000000     0.359    0.864  ...
# 3          0.000000     0.306    0.333  ...
# 4          0.000000     0.171    0.463  ...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/7G...
# 1  {'spotify': 'https://open.spotify.com/track/5m...
# 2  {'spotify': 'https://open.spotify.com/track/0c...
# 3  {'spotify': 'https://open.spotify.com/track/0s...
# 4  {'spotify': 'https://open.spotify.com/track/3w...
#
#                                                 href is_local is_playable  \
# 0  https://api.spotify.com/v1/tracks/7GJRZmyEpMIo...    False        True
# 1  https://api.spotify.com/v1/tracks/5mY6WIHXoBsO...    False        True
# 2  https://api.spotify.com/v1/tracks/0cyQuiFTVaHM...    False        True
# 3  https://api.spotify.com/v1/tracks/0sZHxhoBaK0Y...    False        True
# 4  https://api.spotify.com/v1/tracks/3wy4se12ucUN...    False        True
#
#                     name popularity  \
# 0  HONEY (ARE U COMING?)         57
# 1              VALENTINE         65
# 2            OFF MY FACE         65
# 3             THE DRIVER         64
# 4             TRASTEVERE         60
#
#                                          preview_url  track_number type_y  \
# 0  https://p.scdn.co/mp3-preview/3fe024604adacec1...             1  track
# 1  https://p.scdn.co/mp3-preview/1712dcb919665a9b...             2  track
# 2  https://p.scdn.co/mp3-preview/e1b3d8a2b268b17e...             3  track
# 3  https://p.scdn.co/mp3-preview/72be7cc52c4e5607...             4  track
# 4  https://p.scdn.co/mp3-preview/25d6ac4def73ba6f...             5  track
#
#                                   uri_y
# 0  spotify:track:7GJRZmyEpMIou1RqG0ebd8
# 1  spotify:track:5mY6WIHXoBsOCSyQxrTg0E
# 2  spotify:track:0cyQuiFTVaHM70y8xRsOWA
# 3  spotify:track:0sZHxhoBaK0YEvvMV8blr6
# 4  spotify:track:3wy4se12ucUNAfRwZpmDuz
#
# [5 rows x 34 columns]

# %% [markdown]
# Merges the Maneskin features and trakcs into one table and shows the first 5 tracks

# %%
ms_merged.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type_x', 'id', 'uri_x', 'track_href', 'analysis_url', 'duration_ms_x',
#        'time_signature', 'album', 'artists', 'disc_number', 'duration_ms_y',
#        'explicit', 'external_ids', 'external_urls', 'href', 'is_local',
#        'is_playable', 'name', 'popularity', 'preview_url', 'track_number',
#        'type_y', 'uri_y'],
#       dtype='object')

# %% [markdown]
# Shows the columns that are within ms_merged

# %%
ac_merged = pd.merge(ac_features_df, ac_tracks_df, how = 'inner', on = 'id')
ms_merged['artist'] = "Maneskin"
ac_merged['artist'] = "AC/DC"

# %% [markdown]
# Merges the AC/DC features and tracks into one table
# Adds the "Artist" column with "Maneskin" for their albumn
# Adds the "Artist" column with "AC/DC" for their album

# %%
artist_compare = pd.concat([ms_merged, ac_merged], axis = 0)
artist_compare
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.475   0.939    7    -2.353     0       0.0798      0.002080
# 1          0.475   0.716    2    -4.526     0       0.0277      0.007060
# 2          0.794   0.801   11    -3.006     0       0.0603      0.001950
# 3          0.321   0.827    9    -4.238     0       0.0878      0.000851
# 4          0.604   0.542   11    -2.942     0       0.0242      0.605000
# 5          0.684   0.756    1    -4.783     0       0.0260      0.000926
# 6          0.704   0.821    9    -2.974     1       0.0624      0.001810
# 7          0.480   0.585    4    -4.196     1       0.0307      0.002770
# 8          0.735   0.729    2    -3.338     1       0.0783      0.015700
# 9          0.621   0.715    6    -4.040     0       0.0323      0.000980
# 10         0.567   0.692    5    -3.743     0       0.0630      0.000217
# 11         0.626   0.652    9    -3.519     1       0.1000      0.000410
# 12         0.523   0.914    2    -4.873     1       0.0521      0.000030
# 13         0.489   0.801    1    -2.357     1       0.0813      0.003510
# 14         0.520   0.433    9    -6.585     1       0.0283      0.587000
# 15         0.547   0.856    7    -5.183     1       0.0517      0.000183
# 16         0.443   0.962    4    -1.844     0       0.0638      0.001790
# 17         0.504   0.981    2    -2.265     1       0.0926      0.001340
# 18         0.292   0.776    7    -4.455     0       0.0278      0.000670
# 19         0.767   0.676    1    -3.282     0       0.0646      0.000621
# 0          0.389   0.873    4    -4.768     0       0.0475      0.005320
# 1          0.457   0.904    2    -5.303     1       0.0747      0.000239
# 2          0.532   0.858    9    -5.023     1       0.0599      0.005330
# 3          0.525   0.975    2    -4.372     1       0.0572      0.070400
# 4          0.400   0.902    9    -4.385     1       0.0523      0.115000
# 5          0.310   0.700    9    -5.678     1       0.0470      0.011000
# 6          0.532   0.767    7    -5.509     1       0.0574      0.002870
# 7          0.421   0.889    2    -5.166     1       0.0545      0.001670
# 8          0.417   0.942    4    -4.225     1       0.0852      0.023400
# 9          0.576   0.659    9    -5.617     1       0.0383      0.041000
#
#     instrumentalness  liveness  valence  ...  \
# 0           0.000002    0.1590    0.375  ...
# 1           0.000007    0.1300    0.217  ...
# 2           0.000000    0.3590    0.864  ...
# 3           0.000000    0.3060    0.333  ...
# 4           0.000000    0.1710    0.463  ...
# 5           0.000116    0.0486    0.681  ...
# 6           0.000000    0.0981    0.915  ...
# 7           0.000000    0.0623    0.269  ...
# 8           0.000000    0.1600    0.880  ...
# 9           0.000000    0.0781    0.598  ...
# 10          0.047900    0.1060    0.351  ...
# 11          0.005740    0.0781    0.571  ...
# 12          0.000210    0.3420    0.766  ...
# 13          0.000010    0.1440    0.290  ...
# 14          0.000173    0.0942    0.291  ...
# 15          0.000078    0.0771    0.687  ...
# 16          0.000000    0.4240    0.234  ...
# 17          0.000000    0.2060    0.571  ...
# 18          0.014400    0.1220    0.310  ...
# 19          0.000000    0.0977    0.792  ...
# 0           0.005500    0.2730    0.303  ...
# 1           0.087900    0.3960    0.480  ...
# 2           0.000002    0.7510    0.495  ...
# 3           0.000022    0.2310    0.736  ...
# 4           0.000116    0.1390    0.632  ...
# 5           0.009650    0.0828    0.763  ...
# 6           0.000513    0.3900    0.755  ...
# 7           0.008380    0.6540    0.424  ...
# 8           0.008570    0.3170    0.618  ...
# 9           0.000000    0.0587    0.717  ...
#
#                                                  href is_local is_playable  \
# 0   https://api.spotify.com/v1/tracks/7GJRZmyEpMIo...    False        True
# 1   https://api.spotify.com/v1/tracks/5mY6WIHXoBsO...    False        True
# 2   https://api.spotify.com/v1/tracks/0cyQuiFTVaHM...    False        True
# 3   https://api.spotify.com/v1/tracks/0sZHxhoBaK0Y...    False        True
# 4   https://api.spotify.com/v1/tracks/3wy4se12ucUN...    False        True
# 5   https://api.spotify.com/v1/tracks/1yORwrLynitf...    False        True
# 6   https://api.spotify.com/v1/tracks/5FjRyRqZlgrM...    False        True
# 7   https://api.spotify.com/v1/tracks/0WbzKaO91ulI...    False        True
# 8   https://api.spotify.com/v1/tracks/17PVZrZPFBjF...    False        True
# 9   https://api.spotify.com/v1/tracks/5qFoSIpmfXex...    False        True
# 10  https://api.spotify.com/v1/tracks/6k01DY0P3ztc...    False        True
# 11  https://api.spotify.com/v1/tracks/6pUcoYKUZzgB...    False        True
# 12  https://api.spotify.com/v1/tracks/1SBNKGLIg5uZ...    False        True
# 13  https://api.spotify.com/v1/tracks/0JlowC3ck7YY...    False        True
# 14  https://api.spotify.com/v1/tracks/3kpTSEwdJAzy...    False        True
# 15  https://api.spotify.com/v1/tracks/6nzBnBFS64mf...    False        True
# 16  https://api.spotify.com/v1/tracks/66F8TOWVZ6bA...    False        True
# 17  https://api.spotify.com/v1/tracks/2uiUNqiTH1pr...    False        True
# 18  https://api.spotify.com/v1/tracks/5QoKT6BRoQwt...    False        True
# 19  https://api.spotify.com/v1/tracks/2y5ljQNRVVP1...    False        True
# 0   https://api.spotify.com/v1/tracks/69QHm3pustz0...    False        True
# 1   https://api.spotify.com/v1/tracks/0C80GCp0mMuB...    False        True
# 2   https://api.spotify.com/v1/tracks/6Th6ND8RQPyw...    False        True
# 3   https://api.spotify.com/v1/tracks/6rAy2MsMUabb...    False        True
# 4   https://api.spotify.com/v1/tracks/5XeMsYb1rWxQ...    False        True
# 5   https://api.spotify.com/v1/tracks/08mG3Y1vljYA...    False        True
# 6   https://api.spotify.com/v1/tracks/2SiXAy7TuUky...    False        True
# 7   https://api.spotify.com/v1/tracks/4dDurgTN3eGy...    False        True
# 8   https://api.spotify.com/v1/tracks/2MCUmp0I98gs...    False        True
# 9   https://api.spotify.com/v1/tracks/6J17MkMmuzBi...    False        True
#
#                                    name popularity  \
# 0                 HONEY (ARE U COMING?)         57
# 1                             VALENTINE         65
# 2                           OFF MY FACE         65
# 3                            THE DRIVER         64
# 4                            TRASTEVERE         60
# 5                           OWN MY MIND         53
# 6            GOSSIP (feat. Tom Morello)         53
# 7                              TIMEZONE         52
# 8                           BLA BLA BLA         52
# 9                             BABY SAID         53
# 10                             GASOLINE         52
# 11                                 FEEL         51
# 12                    DON'T WANNA SLEEP         51
# 13                            KOOL KIDS         49
# 14                       IF NOT FOR YOU         49
# 15                      READ YOUR DIARY         51
# 16                         MARK CHAPMAN         50
# 17                              LA FINE         48
# 18                   IL DONO DELLA VITA         47
# 19                             MAMMAMIA         52
# 0                           Hells Bells         74
# 1                       Shoot to Thrill         71
# 2        What Do You Do for Money Honey         53
# 3                  Givin the Dog a Bone         51
# 4           Let Me Put My Love Into You         51
# 5                         Back In Black         83
# 6           You Shook Me All Night Long         83
# 7                    Have a Drink on Me         59
# 8                           Shake a Leg         48
# 9   Rock and Roll Ain't Noise Pollution         59
#
#                                           preview_url  track_number  type_y  \
# 0   https://p.scdn.co/mp3-preview/3fe024604adacec1...             1   track
# 1   https://p.scdn.co/mp3-preview/1712dcb919665a9b...             2   track
# 2   https://p.scdn.co/mp3-preview/e1b3d8a2b268b17e...             3   track
# 3   https://p.scdn.co/mp3-preview/72be7cc52c4e5607...             4   track
# 4   https://p.scdn.co/mp3-preview/25d6ac4def73ba6f...             5   track
# 5   https://p.scdn.co/mp3-preview/3b6630b594c1d309...             6   track
# 6   https://p.scdn.co/mp3-preview/8335aa630f18a1b3...             7   track
# 7   https://p.scdn.co/mp3-preview/b66ac80d0a9b2cd8...             8   track
# 8   https://p.scdn.co/mp3-preview/a75cab157813dfcc...             9   track
# 9   https://p.scdn.co/mp3-preview/61e029e6ceb86d16...            10   track
# 10  https://p.scdn.co/mp3-preview/3d22ccc4bdbf3f26...            11   track
# 11  https://p.scdn.co/mp3-preview/0b44b3ca4f333765...            12   track
# 12  https://p.scdn.co/mp3-preview/0834f3f95d62eeaf...            13   track
# 13  https://p.scdn.co/mp3-preview/f1eab7b169150fa1...            14   track
# 14  https://p.scdn.co/mp3-preview/11d12118cc331493...            15   track
# 15  https://p.scdn.co/mp3-preview/d479c9f85339cc86...            16   track
# 16  https://p.scdn.co/mp3-preview/cdad58f0378cfc74...            17   track
# 17  https://p.scdn.co/mp3-preview/42bf789b8980a58c...            18   track
# 18  https://p.scdn.co/mp3-preview/62a007e2473bd1e0...            19   track
# 19  https://p.scdn.co/mp3-preview/be8493887bd497a8...            20   track
# 0   https://p.scdn.co/mp3-preview/63f8bf5471d413be...             1   track
# 1   https://p.scdn.co/mp3-preview/98123a7d31111d0d...             2   track
# 2   https://p.scdn.co/mp3-preview/dd7c0dfc725d743d...             3   track
# 3   https://p.scdn.co/mp3-preview/932aaa54222256af...             4   track
# 4   https://p.scdn.co/mp3-preview/88a64c566ec2b262...             5   track
# 5   https://p.scdn.co/mp3-preview/81e64fa3a306418f...             6   track
# 6   https://p.scdn.co/mp3-preview/3b01294b6b0458fe...             7   track
# 7   https://p.scdn.co/mp3-preview/c55cfbeac38cf82b...             8   track
# 8   https://p.scdn.co/mp3-preview/4d0e3efac7da4643...             9   track
# 9   https://p.scdn.co/mp3-preview/48134c10f34bb8e7...            10   track
#
#                                    uri_y    artist
# 0   spotify:track:7GJRZmyEpMIou1RqG0ebd8  Maneskin
# 1   spotify:track:5mY6WIHXoBsOCSyQxrTg0E  Maneskin
# 2   spotify:track:0cyQuiFTVaHM70y8xRsOWA  Maneskin
# 3   spotify:track:0sZHxhoBaK0YEvvMV8blr6  Maneskin
# 4   spotify:track:3wy4se12ucUNAfRwZpmDuz  Maneskin
# 5   spotify:track:1yORwrLynitfD8HoPipXlg  Maneskin
# 6   spotify:track:5FjRyRqZlgrM4tfzVhIKGA  Maneskin
# 7   spotify:track:0WbzKaO91ulIuqn3WNbEiT  Maneskin
# 8   spotify:track:17PVZrZPFBjFhNqx0YLF7o  Maneskin
# 9   spotify:track:5qFoSIpmfXexkhCpD1E1aY  Maneskin
# 10  spotify:track:6k01DY0P3ztcD75wSYWUsk  Maneskin
# 11  spotify:track:6pUcoYKUZzgBNokZ3IYCfA  Maneskin
# 12  spotify:track:1SBNKGLIg5uZgSTjZhSTMr  Maneskin
# 13  spotify:track:0JlowC3ck7YYDm1mACwHwF  Maneskin
# 14  spotify:track:3kpTSEwdJAzygDttaU0614  Maneskin
# 15  spotify:track:6nzBnBFS64mfZRHj4ncdx6  Maneskin
# 16  spotify:track:66F8TOWVZ6bAdS7oVZ52in  Maneskin
# 17  spotify:track:2uiUNqiTH1prcwDZ47OMRX  Maneskin
# 18  spotify:track:5QoKT6BRoQwtP1Z7mH7vWV  Maneskin
# 19  spotify:track:2y5ljQNRVVP1VVkHw0XsBG  Maneskin
# 0   spotify:track:69QHm3pustz01CJRwdo20z     AC/DC
# 1   spotify:track:0C80GCp0mMuBzLf3EAXqxv     AC/DC
# 2   spotify:track:6Th6ND8RQPywiyelecP5Lf     AC/DC
# 3   spotify:track:6rAy2MsMUabbqu2VygrblP     AC/DC
# 4   spotify:track:5XeMsYb1rWxQL1bUUaZajn     AC/DC
# 5   spotify:track:08mG3Y1vljYA6bvDt4Wqkj     AC/DC
# 6   spotify:track:2SiXAy7TuUkycRVbbWDEpo     AC/DC
# 7   spotify:track:4dDurgTN3eGyU0ghzFJ0T1     AC/DC
# 8   spotify:track:2MCUmp0I98gsJBmey7DfZS     AC/DC
# 9   spotify:track:6J17MkMmuzBiIOjRH6MOBZ     AC/DC
#
# [30 rows x 35 columns]

# %% [markdown]
# Final merged table that compares both albumns, added with the artist names, and adds in all of the audio feature columns.

# %%
artist_df_tidy = artist_compare.drop(columns = ['key', 'mode', 'uri_x', 'album', 'artists', 'href', 'preview_url', 'analysis_url', 'duration_ms_x', 'time_signature', 'tempo', 'type_x', 'id', 'track_href', 'duration_ms_y', 'explicit', 'external_ids', 'external_urls', 'speechiness', 'liveness', 'valence', 'is_local', 'is_playable', 'type_y', 'uri_y'])
artist_df_tidy
#Creates a tidy table by dropping some of the columns and leaving the columns that I want to look at.
# Out:
#     danceability  energy  loudness  acousticness  instrumentalness  \
# 0          0.475   0.939    -2.353      0.002080          0.000002
# 1          0.475   0.716    -4.526      0.007060          0.000007
# 2          0.794   0.801    -3.006      0.001950          0.000000
# 3          0.321   0.827    -4.238      0.000851          0.000000
# 4          0.604   0.542    -2.942      0.605000          0.000000
# 5          0.684   0.756    -4.783      0.000926          0.000116
# 6          0.704   0.821    -2.974      0.001810          0.000000
# 7          0.480   0.585    -4.196      0.002770          0.000000
# 8          0.735   0.729    -3.338      0.015700          0.000000
# 9          0.621   0.715    -4.040      0.000980          0.000000
# 10         0.567   0.692    -3.743      0.000217          0.047900
# 11         0.626   0.652    -3.519      0.000410          0.005740
# 12         0.523   0.914    -4.873      0.000030          0.000210
# 13         0.489   0.801    -2.357      0.003510          0.000010
# 14         0.520   0.433    -6.585      0.587000          0.000173
# 15         0.547   0.856    -5.183      0.000183          0.000078
# 16         0.443   0.962    -1.844      0.001790          0.000000
# 17         0.504   0.981    -2.265      0.001340          0.000000
# 18         0.292   0.776    -4.455      0.000670          0.014400
# 19         0.767   0.676    -3.282      0.000621          0.000000
# 0          0.389   0.873    -4.768      0.005320          0.005500
# 1          0.457   0.904    -5.303      0.000239          0.087900
# 2          0.532   0.858    -5.023      0.005330          0.000002
# 3          0.525   0.975    -4.372      0.070400          0.000022
# 4          0.400   0.902    -4.385      0.115000          0.000116
# 5          0.310   0.700    -5.678      0.011000          0.009650
# 6          0.532   0.767    -5.509      0.002870          0.000513
# 7          0.421   0.889    -5.166      0.001670          0.008380
# 8          0.417   0.942    -4.225      0.023400          0.008570
# 9          0.576   0.659    -5.617      0.041000          0.000000
#
#     disc_number                                 name  popularity  \
# 0             1                HONEY (ARE U COMING?)          57
# 1             1                            VALENTINE          65
# 2             1                          OFF MY FACE          65
# 3             1                           THE DRIVER          64
# 4             1                           TRASTEVERE          60
# 5             1                          OWN MY MIND          53
# 6             1           GOSSIP (feat. Tom Morello)          53
# 7             1                             TIMEZONE          52
# 8             1                          BLA BLA BLA          52
# 9             1                            BABY SAID          53
# 10            1                             GASOLINE          52
# 11            1                                 FEEL          51
# 12            1                    DON'T WANNA SLEEP          51
# 13            1                            KOOL KIDS          49
# 14            1                       IF NOT FOR YOU          49
# 15            1                      READ YOUR DIARY          51
# 16            1                         MARK CHAPMAN          50
# 17            1                              LA FINE          48
# 18            1                   IL DONO DELLA VITA          47
# 19            1                             MAMMAMIA          52
# 0             1                          Hells Bells          74
# 1             1                      Shoot to Thrill          71
# 2             1       What Do You Do for Money Honey          53
# 3             1                 Givin the Dog a Bone          51
# 4             1          Let Me Put My Love Into You          51
# 5             1                        Back In Black          83
# 6             1          You Shook Me All Night Long          83
# 7             1                   Have a Drink on Me          59
# 8             1                          Shake a Leg          48
# 9             1  Rock and Roll Ain't Noise Pollution          59
#
#     track_number    artist
# 0              1  Maneskin
# 1              2  Maneskin
# 2              3  Maneskin
# 3              4  Maneskin
# 4              5  Maneskin
# 5              6  Maneskin
# 6              7  Maneskin
# 7              8  Maneskin
# 8              9  Maneskin
# 9             10  Maneskin
# 10            11  Maneskin
# 11            12  Maneskin
# 12            13  Maneskin
# 13            14  Maneskin
# 14            15  Maneskin
# 15            16  Maneskin
# 16            17  Maneskin
# 17            18  Maneskin
# 18            19  Maneskin
# 19            20  Maneskin
# 0              1     AC/DC
# 1              2     AC/DC
# 2              3     AC/DC
# 3              4     AC/DC
# 4              5     AC/DC
# 5              6     AC/DC
# 6              7     AC/DC
# 7              8     AC/DC
# 8              9     AC/DC
# 9             10     AC/DC

# %% [markdown]
# Some of the things that were hard to work with was the Spotify keys with their need to be exact. After getting the keys to work, the rest of the project was relatively easy to work through since much of the information was pulled from previous exercises and notes from class. Some limitations within the data is that spotify deletes data after a specific amount of time so there is a chance that the data is not entirely accurate. I chose these two alubms since they are categorized within the same genre of music, but from different time periods. I wanted to show how the genre has changed over time while also showing how some characteristics have stayed the same over the years.
